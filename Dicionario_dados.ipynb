# %%
import pandas as pd

# %%
# Configurando para mostrar todo o arquivo
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Visuazliando o arquivo
df = pd.read_excel('Dicionário_Microdados_Enem_2022.xlsx')
df
# Out:
#                    DICIONÁRIO DE VARIÁVEIS - ENEM 2022  \
# 0                                                  NaN
# 1                                     NOME DA VARIÁVEL
# 2                                                  NaN
# 3                                DADOS DO PARTICIPANTE
# 4                                         NU_INSCRICAO
# 5                                               NU_ANO
# 6                                      TP_FAIXA_ETARIA
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# ...
